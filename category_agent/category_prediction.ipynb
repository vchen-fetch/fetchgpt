# %%
import pandas as pd

# %%
from category_tree import CategoryTree
from category_agent import CategoryAssignmentAgent
import getpass
from pprint import pprint
from tqdm.notebook import tqdm
import json
import asyncio
from tqdm.asyncio import tqdm_asyncio

# %%
OPENAI_API_KEY = getpass.getpass()

# %%
df = pd.read_csv("categories_data.csv")

# %%
df.CATEGORY_NAME_HIERARCHY.values[:4]
# Out:
# array(['Beverages > Fruit & Vegetable Juices > Wellness Shots',
#        'Beverages > Fruit & Vegetable Juices > Other Juices',
#        'Apparel & Accessories > Clothing > Underwear & Socks > Shapewear',
#        'Pantry > Packaged Fruit & Applesauce > Other Packaged Fruit'],
#       dtype=object)

# %%
categories_hierarchy = df.CATEGORY_NAME_HIERARCHY.unique()

# %%
categories_hierarchy
# Out:
# array(['Beverages > Fruit & Vegetable Juices > Wellness Shots',
#        'Beverages > Fruit & Vegetable Juices > Other Juices',
#        'Apparel & Accessories > Clothing > Underwear & Socks > Shapewear',
#        'Pantry > Packaged Fruit & Applesauce > Other Packaged Fruit',
#        'Sporting Goods > Athletics > Water Sports',
#        'Beverages > Drink Mixes > Energy & Hydration Mixes',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Dish Soap',
#        'Beverages > Drink Mixes > Protein Powder',
#        'Beverages > Carbonated Soft Drinks > Cola > Zero Sugar Cola',
#        'Pantry > Packaged Seafood > Other Packaged Seafood',
#        'Snacks > Nuts & Seeds > Other Nuts',
#        'Pantry > Cooking & Baking > Starches & Thickeners',
#        'Apparel & Accessories > Clothing > Maternity Clothing',
#        'Apparel & Accessories > Clothing > Sweaters & Sweatshirts',
#        'Pantry > Rice & Grains > Rice Blends',
#        'Apparel & Accessories > Clothing > Outerwear > Tops',
#        'Health & Wellness > Deodorant & Antiperspirant > Gender Neutral Deodorant & Antiperspirant',
#        'Snacks > Candy > Candy Variety Pack',
#        'Beverages > Fruit & Vegetable Juices > Coconut Water',
#        'Snacks > Nuts & Seeds > Pistachios',
#        'Beauty > Nail Care > Nail Treatments',
#        'Health & Wellness > Hair Care > Dry Shampoo',
#        'Restaurant > À La Carte Item > Cereal',
#        'Restaurant > Toppings & Fillings > Bacon & Bacon Bits',
#        'Apparel & Accessories > Clothing > Bottoms',
#        'Snacks > Nuts & Seeds > Covered Nuts',
#        'Restaurant > Toppings & Fillings > Cilantro',
#        'Home & Garden > Hardware > Building Consumables > Hardware Glue & Adhesives',
#        'Home & Garden > Hardware > Tools > Nailers & Staplers',
#        'Home & Garden > Hardware > Hardware Accessories > Tool Storage & Organization',
#        'Home & Garden > Hardware > Tools > Paint Tools & Accessories',
#        'Home & Garden > Hardware > Tools > Plungers',
#        'Home & Garden > Hardware > Building Consumables > Masonry Consumables > Cement, Mortar & Concrete Mixes',
#        'Home & Garden > Hardware',
#        'Meat & Seafood > Fresh Chicken > Fresh Ground Chicken',
#        'Dairy > Cheese > Sliced Cheese > Processed Sliced Cheese',
#        'Dairy > Cheese > Cheese Snacks > Individually Packaged Cheese Snacks',
#        'Snacks > Dips & Salsa > Other Dips',
#        'Snacks > Crackers > Other Crackers',
#        'Snacks > Variety Snack Packs',
#        'Pantry > Cooking & Baking > Baking Ingredients > Evaporated Milk',
#        'Pantry > Cooking & Baking > Sugars & Sweeteners > Pancake & Waffle Syrup',
#        'Snacks > Nuts & Seeds > Snack Seeds',
#        'Meat & Seafood > Fresh Bacon > Other Meats Bacon',
#        'Deli & Bakery > Prepared Meals > Prepared Snack Pack',
#        'Alcohol > Wine > Red Wine > Other Red Wines',
#        'Fees > Money Order',
#        'Alcohol > Beer > Lager > Imported Lager > Non-Mexican Style Imported Lager',
#        'Beauty > Cosmetic Tools > Makeup Tools > Eyeliner Pencil Sharpener',
#        'Health & Wellness > Hair Care > Shampoo & Conditioner Combinations',
#        'Mature > Lottery Tickets',
#        'Produce > Fresh Fruits > Fresh Nectarines',
#        'Dairy > Cream > Buttermilk',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Sides > Stovetop Mashed Potatoes',
#        'Frozen > Frozen Desserts > Frozen Non-Dairy Dessert > Frozen Non-Dairy Ice Cream Substitutes',
#        'Snacks > Snack Cakes > Muffin Snack Cakes',
#        'Snacks > Fruit & Vegetable Snacks > Dried Vegetables',
#        'Sporting Goods > Athletics > Baseball & Softball',
#        'Produce > Fresh Vegetables > Fresh Squash & Pumpkins',
#        'Snacks > Puffed Snacks > Popcorn > Already Popped Popcorn',
#        'Apparel & Accessories > Clothing > Baby & Toddler Clothing > Baby & Toddler Bottoms',
#        'Dairy > Dairy Alternatives > Non-Dairy Yogurt & Smoothies',
#        'Pantry > Nut Butters & Jam > Jellies, Jams, & Preserves',
#        'Beverages > Coffee',
#        'Alcohol > Beer > Lager > American Lager > Regular American Lager',
#        'Dairy > Cream > Heavy Cream', 'Beauty > Body Fragrances',
#        'Household Supplies > Household Paper Products > Disposable Tableware > Disposable Silverware',
#        'Apparel & Accessories > Clothing > Underwear & Socks > Socks',
#        'Health & Wellness > Medicines & Treatments > Vitamins & Herbal Supplements',
#        'Dairy > Cheese', 'Meat & Seafood > Specialty Meats',
#        'Snacks > Nuts & Seeds > Mixed Nuts',
#        'Pantry > Dressings > French Dressing',
#        'Produce > Fresh Fruits > Fresh Berries > Fresh Blueberries',
#        'Frozen > Frozen Fruits > Frozen Fruit Puree',
#        'Health & Wellness > Eye Care > Eye Drops',
#        'Pantry > Cooking & Baking > Spices & Seasonings > Pepper',
#        'Pantry > Sauces & Marinades > Marinades & Rubs',
#        'Deli & Bakery > Prepared Meals > Sushi',
#        'Health & Wellness > Skin Care > Acne Treatments & Kits',
#        'Home & Garden > Linens & Bedding > Bedding > Pillows',
#        'Apparel & Accessories > Clothing > Activewear',
#        'Household Supplies > Pest Control > Pest Repellents > Household Insect Repellents',
#        'Meat & Seafood > Fresh Turkey > Fresh Ground Turkey',
#        'Baby & Toddler > Baby & Toddler Feeding > Baby Food Prep & Accessories',
#        'Health & Wellness > Ear Care > Cotton Swabs',
#        'Health & Wellness > Bath & Body > Body Wash',
#        'Snacks > Chips > Pork Skins',
#        'Meat & Seafood > Fresh Bacon > Turkey Bacon',
#        'Snacks > Dips & Salsa > Salsa',
#        'Household Supplies > Pest Control > Pest Repellents',
#        'Meat & Seafood > Fresh Pork > Ham', 'Dairy > Refrigerated Doughs',
#        "Health & Wellness > Hair Removal > Razors > Women's Razors",
#        'Beverages > Coffee > Ready-To-Drink Coffee',
#        'Household Supplies > Laundry Supplies > Fabric Softeners & Dryer Sheets',
#        'Home & Garden > Plants > Indoor & Outdoor Plants',
#        'Snacks > Pretzels > Traditional Pretzels',
#        'Pantry > Packaged Vegetables > Corn',
#        'Beverages > Water > Sparkling Water > Flavored Sparkling Water',
#        'Pantry > Packaged Vegetables > Mushrooms',
#        'Vehicles & Parts > Motor Vehicle Parts',
#        'Snacks > Chips > Corn Chips',
#        'Dairy > Yogurt > Traditional Yogurt',
#        'Pantry > Sauces & Marinades > Gravy',
#        'Pantry > Packaged Meals & Sides > Microwavable Entrees',
#        'Beverages > Fruit & Vegetable Juices > Lemonade & Limeade',
#        'Pantry > Packaged Meals & Sides',
#        'Pantry > Packaged Vegetables > Carrots',
#        'Apparel & Accessories > Clothing Accessories > Gloves & Mittens',
#        'Alcohol > Spirits > Whiskey > American Whiskey',
#        'Health & Wellness > Bath & Body > Bar Soap',
#        'Snacks > Snack Cakes', 'Snacks > Chips > Potato Chips',
#        'Health & Wellness > Hair Care > Conditioner',
#        'Snacks > Pretzels > Filled Pretzels',
#        'Pantry > Dressings > Italian Dressing',
#        'Health & Wellness > Medicines & Treatments > Cough & Cold Medicines & Treatments > Cough Drops & Lozenges',
#        'Snacks > Candy > Confection Candy', 'Snacks > Candy',
#        'Toys & Games > Games > Card Games',
#        'Beverages > Carbonated Soft Drinks > Soda > Specialty & Cream Sodas',
#        'Household Supplies > Laundry Supplies',
#        'Pantry > Cooking & Baking > Pasta Sauce > Red Pasta Sauce',
#        'Baby & Toddler > Baby Health > Pacifiers & Teethers',
#        'Apparel & Accessories > Clothing > Sleepwear & Loungewear',
#        'Health & Wellness > Medicines & Treatments > Skin Treatments',
#        'Dairy > Cream > Sour Cream',
#        'Baby & Toddler > Baby & Toddler Feeding > Baby & Toddler Food > Baby Food & Cereal',
#        'Produce > Fresh Fruits > Fresh Melons',
#        'Snacks > Crackers > Cheese Crackers',
#        'Pantry > Nut Butters & Jam > Peanut Butter',
#        'Alcohol > Spirits > Sake & Rice Wines',
#        'Produce > Fresh Vegetables > Fresh Root Vegetables',
#        'Home & Garden > Kitchen & Dining > Cookware & Bakeware > Cookware > Pressure Cookers & Canners',
#        'Produce > Fresh Fruits > Fresh Berries > Fresh Strawberries',
#        'Animals & Pet Supplies > Bird Supplies > Bird Food',
#        'Pantry > Cooking & Baking > Baking Staples > Flavoring Extracts',
#        'Health & Wellness > Oral Care > Oral Pain Relief',
#        'Household Supplies > Household Paper Products > Disposable Tableware > Disposable Cups',
#        'Animals & Pet Supplies > Fish Supplies > Fish Food',
#        'Alcohol > Wine > White Wine > Sauvignon Blanc',
#        'Snacks > Trail Mix',
#        'Produce > Fresh Vegetables > Fresh Lettuce & Leafy Greens',
#        'Pantry > Nut Butters & Jam', 'Pantry > Pickled Goods > Olives',
#        'Pantry > Condiments > Specialty Sauces',
#        'Alcohol > Spirits > Cordials & Liqueurs',
#        'Household Supplies > Household Cleaning Supplies > Drain Cleaners',
#        'Pantry > Packaged Vegetables > Beans',
#        'Meat & Seafood > Fresh Turkey > Fresh Turkey Breasts',
#        'Pantry > Bread > Bagels',
#        'Pantry > Packaged Seafood > Packaged Salmon',
#        'Snacks > Crackers > Wheat Crackers', 'Alcohol > Spirits > Rum',
#        'Health & Wellness > Skin Care > Lip Balms & Treatments > Lip Balms',
#        'Health & Wellness > Skin Care > Sunscreen',
#        'Snacks > Snack Bars > Performance & Protein Bars',
#        'Deli & Bakery > Prepared Meals > Sides & Salads',
#        'Health & Wellness > Medicines & Treatments > Allergy & Sinus Medicines & Treatments',
#        'Meat & Seafood > Fresh Seafood > Fresh Fish',
#        'Snacks > Dips & Salsa > French Onion Dip',
#        'Pantry > Dressings > Croutons & Salad Toppings',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Sides > Stovetop Rice Sides',
#        'Frozen > Frozen Sides > Frozen Potatoes',
#        'Household Supplies > Lighters & Matches > Matches, Lighters & Accessories',
#        'Household Supplies > Household Cleaning Supplies > Sponges & Scrub Brushes',
#        'Animals & Pet Supplies > Pet Food Containers & Scoops',
#        'Home & Garden > Kitchen & Dining > Cookware & Bakeware > Bakeware > Pizza Stones & Pans',
#        'Media > Books & Accessories',
#        'Beverages > Sports Drinks & Enhanced Waters > Sports & Electrolyte Drinks',
#        'Snacks > Snack Bars > Granola, Fruit & Nut Bars',
#        'Pantry > Condiments > Mayonnaise',
#        'Produce > Fresh Fruits > Fresh Berries > Fresh Blackberries',
#        'Fees', 'Pantry',
#        'Frozen > Frozen Meat > Frozen Chicken > Frozen Chicken Breasts & Tenders',
#        'Beverages > Coffee > Coffee Flavorings > Coffee Flavoring Creamers',
#        'Health & Wellness > Medicines & Treatments > Cough & Cold Medicines & Treatments > Cold & Flu Medicines & Treatments',
#        'Beverages > Water > Sparkling Water',
#        'Health & Wellness > Adult Incontinence > Adult Incontinence Underwear',
#        'Beverages > Tea > Iced Teas',
#        'Beauty > Makeup > Eye Makeup > Eye Primer',
#        'Frozen > Frozen Desserts',
#        'Household Supplies > Household Cleaning Supplies > Shop Towels & General-Purpose Cleaning Cloths',
#        'Meat & Seafood > Lunch Meat > Turkey Lunch Meat',
#        'Pantry > Condiments > Steak Sauce',
#        'Pantry > Sauces & Marinades > Hot Sauce',
#        'Home & Garden > Plants > Trees',
#        'Pantry > Cooking & Baking > Sugars & Sweeteners > Granulated Sugar',
#        'Beverages > Meal Replacement Beverages > Protein Shakes',
#        'Beverages > Tea > Other RTD Teas', 'Dairy > Cream',
#        'Dairy > Cheese > Crumbled Cheese',
#        'Home & Garden > Linens & Bedding > Towels',
#        'Home & Garden > Kitchen & Dining > Tableware > Dinnerware',
#        'Health & Wellness > First Aid > Bandages & Gauze',
#        'Pantry > Cooking & Baking > Pasta Sauce > Alfredo & White Pasta Sauce',
#        'Produce > Fresh Vegetables > Fresh Celery',
#        'Pantry > Cooking & Baking > Baking Mixes > Pancake & Waffle Mixes',
#        'Snacks > Dessert Toppings > Canned & Whipped Cream',
#        'Produce > Fresh Fruits > Fresh Citrus Fruits',
#        'Snacks > Pudding & Gelatin > Ready-to-Eat Pudding',
#        'Beverages > Water > Purified Water',
#        'Pantry > Packaged Vegetables > Peas',
#        'Beverages > Coffee > Instant Coffee',
#        'Produce > Fresh Fruits > Fresh Avocados',
#        'Pantry > Condiments > Honey Mustard',
#        'Pantry > Bread > Tortillas, Shells, & Wraps',
#        'Produce > Fresh Vegetables > Fresh Eggplant',
#        'Pantry > Bread > English Muffins',
#        'Snacks > Snack Cakes > Rice Treats',
#        'Meat & Seafood > Fresh Pork > Pork Tenderloins',
#        'Household Supplies > Household Paper Products > Disposable Tableware > Disposable Plates & Bowls',
#        'Home & Garden > Decor > Picture Frames',
#        'Pantry > Soup & Broth > Ready to Eat Soup',
#        'Dairy > Dairy Alternatives > Non-Dairy Cheese',
#        'Frozen > Frozen Pizza & Pizza Snacks > Frozen Pizza',
#        'Meat & Seafood > Lunch Meat > Ham Lunch Meat',
#        'Dairy > Dairy Alternatives > Non-Dairy Milk > Oat Milk',
#        'Pantry > Bread > Bread Loaves > French & Italian Bread Loaves',
#        'Dairy > Cheese > Shredded & Grated Cheese',
#        'Health & Wellness > Oral Care > Toothbrushes',
#        'Frozen > Frozen Meals > Frozen Corn Dogs',
#        'Pantry > Rice & Grains > White Rice',
#        'Produce > Fresh Fruits > Fresh Pears',
#        'Meat & Seafood > Fresh Chicken > Fresh Chicken Tenders & Cutlets',
#        'Home & Garden > Kitchen & Dining > Kitchen Tools & Utensils > Can Openers',
#        'Beverages > Coffee > Whole Bean Coffee',
#        'Pantry > Condiments > Ketchup',
#        'Health & Wellness > Topical Muscle & Joint Relief Treatments > Topical & Muscular Medicines & Treatments',
#        'Frozen > Frozen Desserts > Frozen Non-Dairy Dessert > Frozen Non-Dairy Novelties',
#        'Produce > Fresh Fruits > Fresh Grapes', 'Dairy',
#        'Pantry > Cooking & Baking > Baking Mixes > Cake Mix',
#        'Dairy > Butter & Margarine > Spreadable Butter & Margarine',
#        'Toys & Games > Outdoor Play Equipment > Trampolines',
#        'Dairy > Refrigerated Doughs > Refrigerated Pizza Dough',
#        'Apparel & Accessories > Clothing > Underwear & Socks > Underwear',
#        'Household Supplies > Laundry Supplies > Bleach',
#        'Baby & Toddler > Baby & Toddler Feeding > Baby & Toddler Food > Baby Formula',
#        'Frozen > Frozen Desserts > Frozen Dairy Desserts',
#        'Home & Garden > Linens & Bedding > Bedding > Blankets',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > All-Purpose Cleaners',
#        'Pantry > Sauces & Marinades > Hot Sauce > Chili Sauce',
#        'Meat & Seafood > Fresh Bacon > Pork Bacon',
#        'Dairy > Cheese > Cheese Blocks',
#        'Pantry > Cooking & Baking > Baking Ingredients > Marshmallows',
#        'Meat & Seafood > Sausage & Cured Meats > Cured Meats',
#        'Sporting Goods > Outdoor Recreation > Fishing',
#        'Arts & Entertainment > Arts & Crafts > Art & Crafting Materials > Textiles',
#        'Produce > Fresh Fruits > Fresh Apples',
#        'Health & Wellness > First Aid > First Aid Kits',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Entrees > Stovetop Macaroni & Cheese',
#        'Beverages > Juice Drink',
#        "Health & Wellness > Hair Removal > Shaving Gel & Cream > Men's Shaving Gel & Cream",
#        'Produce > Fresh Vegetables > Fresh Mushrooms',
#        'Produce > Fresh Vegetables > Fresh Tomatoes',
#        'Health & Wellness > Bath & Body > Bath Additives',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Carpet Cleaners',
#        'Baby & Toddler > Potty Training > Training Pants',
#        'Baby & Toddler > Diapering > Diaper Rash Treatments',
#        'Deli & Bakery > Deli Counter > Sliced Meat',
#        'Household Supplies > Food Storage',
#        'Snacks > Fruit & Vegetable Snacks > Dried Fruit',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Glass Cleaners',
#        'Produce > Fresh Vegetables > Fresh Cauliflower',
#        'Dairy > Yogurt > Yogurt Drinks',
#        'Pantry > Cooking & Baking > Baking Staples > Baking Cups',
#        'Health & Wellness > Menstrual Care > Tampons',
#        'Frozen > Frozen Meat > Frozen Chicken',
#        'Beverages > Sports Drinks & Enhanced Waters > Enhanced Water',
#        'Produce > Fresh Vegetables > Fresh Peas',
#        'Apparel & Accessories > Jewelry > Earrings',
#        'Baby & Toddler > Diapering > Baby Wipes',
#        'Beverages > Water > Purified Water > Purified Flavored Water',
#        'Frozen > Frozen Breakfast > Frozen Waffles',
#        'Pantry > Cooking & Baking > Vinegars',
#        'Pantry > Cooking & Baking > Pasta Sauce',
#        'Beverages > Carbonated Soft Drinks > Soda > Ginger Ale',
#        'Pantry > Soup & Broth > Condensed Soup',
#        'Household Supplies > Food Storage > Food Storage Containers',
#        'Household Supplies > Household Paper Products',
#        'Beverages > Water > Club Soda',
#        'Home & Garden > Kitchen & Dining > Kitchen Tools & Utensils > Cake Decorating Supplies',
#        'Pantry > Cooking & Baking > Sugars & Sweeteners > Honey',
#        'Health & Wellness > First Aid > Ointments & Liquids',
#        'Frozen > Frozen Appetizers > Frozen Tacos & Taquitos',
#        'Beverages > Tea > Kombucha Tea',
#        'Beverages > Carbonated Soft Drinks > Soda > Lemon-Lime Soda',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Household Disinfectants',
#        'Alcohol > Wine > Red Wine > Cabernet Sauvignon',
#        'Alcohol > Malt Beverages',
#        'Home & Garden > Emergency Preparedness > Furniture Anchors',
#        'Office & School > General Office Supplies > Paper Clips & Clamps > Paper Clips',
#        'Snacks > Crackers',
#        'Deli & Bakery > Prepared Meals > Sandwiches & Wraps',
#        'Arts & Entertainment > Arts & Crafts > Art & Craft Kits',
#        'Alcohol > Beer > Ale > Stout Ale',
#        'Pantry > Cooking & Baking > Baking Staples > Candles & Cake Toppers',
#        'Apparel & Accessories > Clothing > One-Pieces',
#        'Alcohol > Wine > Red Wine > Red Blend',
#        'Frozen > Frozen Meals > Frozen Family Entrées',
#        'Health & Wellness > Skin Care > Facial Lotion & Moisturizer',
#        'Health & Wellness > Medicines & Treatments > Digestive Health Medicines & Treatments > Gas Relief Medicines & Treatments',
#        'Beauty > Makeup > Makeup Removers',
#        'Beverages > Water > Distilled Water',
#        'Pantry > Cooking & Baking > Oils & Sprays > Olive Oil',
#        'Beverages > Coffee > Ground Coffee',
#        'Animals & Pet Supplies > Dog Supplies > Dog Food',
#        'Home & Garden > Kitchen & Dining > Food & Beverage Carriers > Coolers',
#        'Produce > Fresh Fruits > Fresh Plums',
#        'Pantry > Bread > Buns & Rolls',
#        'Deli & Bakery > Bakery > Fresh Baked Bread',
#        'Home & Garden > Lawn & Garden > Gardening > Sands & Soils',
#        'Pantry > Packaged Meat > Packaged Corned Beef',
#        'Meat & Seafood > Sausage & Cured Meats > Hot Dogs',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Floor Cleaners',
#        'Health & Wellness > Skin Care > Lip Balms & Treatments > Medicated Lip Treatments',
#        'Office & School > Presentation Supplies > Chalkboards',
#        'Beverages > Fruit & Vegetable Juices > Juice Blends',
#        'Produce > Fresh Vegetables > Fresh Asparagus',
#        'Beauty > Nail Care > Nail Polishes',
#        'Home & Garden > Decor > Chair & Sofa Cushions',
#        'Beverages > Carbonated Soft Drinks > Soda > Orange Soda',
#        'Snacks > Snack Bars > Meal Replacement Bars',
#        'Health & Wellness > Medicines & Treatments > Digestive Health Medicines & Treatments > Anti Diarrheal Medicines & Treatments',
#        'Snacks > Dips & Salsa > Hummus',
#        'Health & Wellness > Hair Care > Hair Color',
#        'Home & Garden > Kitchen & Dining > Kitchen Appliances > Food Cookers & Steamers',
#        'Alcohol > Spirits > Vodka', 'Dairy > Dairy Alternatives',
#        'Animals & Pet Supplies',
#        'Health & Wellness > Medicines & Treatments > Digestive Health Medicines & Treatments > Heartburn & Antacids Medicines & Treatments',
#        'Arts & Entertainment > Party & Celebration > Gift Giving > Gift Cards & Certificates',
#        'Produce > Prepared Produce > Prepared Fruits',
#        'Snacks > Puffed Snacks > Popcorn > Popcorn Kernels & Popcorn Seasonings',
#        'Beverages > Beverage Syrups',
#        'Beverages > Fruit & Vegetable Juices > Cranberry Juice',
#        'Household Supplies > Pest Control > Pesticides',
#        'Health & Wellness > Medicines & Treatments > Cough & Cold Medicines & Treatments > Cough & Chest Congestion Medicines & Treatments',
#        'Alcohol > Spirits > Brandy & Cognac',
#        'Office & School > Office Instruments > Writing & Drawing Instruments > Markers & Highlighters > Markers',
#        'Dairy > Dairy Alternatives > Non-Dairy Milk',
#        'Alcohol > Beer > Lager > Imported Lager > Mexican-Style Lager > Regular Mexican-Style Lager',
#        'Frozen > Frozen Meals > Frozen Burritos, Pockets & Wraps',
#        'Electronics > Electronics Accessories > Computer & Handheld Device Accessories',
#        'Beauty > Nail Care > False Nails', 'Frozen > Ice',
#        'Alcohol > Wine > White Wine > Pinot Gris & Pinot Grigio',
#        'Beverages',
#        'Dairy > Dairy Alternatives > Non-Dairy Milk > Soy Milk',
#        'Animals & Pet Supplies > Dog Supplies > Dog Toys',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Entrees > Stovetop Pasta Meals',
#        'Snacks > Fruit & Vegetable Snacks > Fruit Rolls & Twists',
#        'Household Supplies > Household Paper Products > Toilet Paper',
#        'Meat & Seafood > Fresh Chicken > Fresh Chicken Breasts',
#        'Pantry > Packaged Vegetables > Vegetable Medley',
#        'Meat & Seafood > Lunch Meat > Bologna',
#        'Pantry > Cereal, Granola, & Toaster Pastries > Breakfast Cereal',
#        'Pantry > Cooking & Baking > Baking Ingredients > Baking Soda & Baking Powder',
#        'Beverages > Fruit & Vegetable Juices',
#        'Snacks > Pudding & Gelatin > Ready-to-Eat Gelatin',
#        'Home & Garden > Kitchen & Dining > Food & Beverage Carriers > Insulated Bags',
#        'Beverages > Cocktail Prep > Non-Alcoholic Cocktail Mixers > Margarita Mix',
#        'Arts & Entertainment > Party & Celebration > Gift Giving > Greeting & Note Cards',
#        'Produce > Fresh Vegetables > Fresh Potatoes',
#        'Vehicles & Parts > Vehicle Maintenance, Care & Decor > Vehicle Fluids',
#        'Produce > Fresh Vegetables > Fresh Cucumbers',
#        'Dairy > Cheese > Cream Cheese & Spreads > Cheese Spreads',
#        'Snacks > Chips > Crisps',
#        'Household Supplies > Household Paper Products > Napkins',
#        'Frozen > Frozen Plant-Based Meat',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Toilet Bowl Cleaners',
#        'Toys & Games > Toys',
#        'Home & Garden > Linens & Bedding > Bedding > Bed Sheets',
#        'Dairy > Dairy Alternatives > Non-Dairy Milk > Nut Milk',
#        'Toys & Games > Games > Board Games', 'Alcohol > Wine > Red Wine',
#        'Arts & Entertainment > Arts & Crafts > Art & Crafting Tools & Accessories',
#        'Beverages > Cocktail Prep > Ginger Beer',
#        'Snacks > Snack Cakes > Donut Snack Cakes',
#        'Frozen > Frozen Desserts > Frozen Dairy Desserts > Frozen Dairy Novelties',
#        'Pantry > Cooking & Baking > Spices & Seasonings > Salt',
#        'Snacks > Jerky & Dried Meat > Dried Meat Sticks',
#        'Health & Wellness > Skin Care > Facial Cleansers',
#        'Home & Garden > Decor > Home Decor Decals',
#        'Household Supplies > Laundry Supplies > Laundry Balls',
#        'Vehicles & Parts > Vehicle Maintenance, Care & Decor',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Washing Machine Cleaners',
#        'Apparel & Accessories > Clothing > Shirts & Tops',
#        'Frozen > Frozen Desserts > Frozen Cake & Sweet Rolls > Frozen Cakes',
#        'Produce > Fresh Vegetables > Fresh Broccoli',
#        'Meat & Seafood > Fresh Beef > Fresh Beef Patties',
#        'Produce > Salad Mixes > Salad Kits',
#        'Health & Wellness > Hair Care > Hair Treatments',
#        'Health & Wellness > Bath & Body > Hand & Body Lotions',
#        'Health & Wellness > Medicines & Treatments > Digestive Health Medicines & Treatments > Constipation Relief Medicines & Treatments',
#        'Snacks > Fruit & Vegetable Snacks > Fruit Snacks',
#        'Arts & Entertainment > Arts & Crafts > Art & Crafting Materials > Crafting Adhesives & Magnets',
#        'Beverages > Fruit & Vegetable Juices > Grape Juice',
#        'Office & School > Filing & Organization > File Folders',
#        'Pantry > Cooking & Baking > Flour & Meal > Gluten Free Flour',
#        'Beverages > Water > Tonic Water',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Dish Detergent',
#        'Home & Garden > Household Appliances > Climate Control Appliances > Air Purifiers & Accessories',
#        'Mature > Tobacco Products & Accessories',
#        'Electronics > Electronics Accessories > Cables & Accessories',
#        'Sporting Goods > Exercise & Fitness > Exercise Mats',
#        'Pantry > Cooking & Baking > Spices & Seasonings > Spices, Seasoning Blends & Grill Rubs',
#        'Health & Wellness > Bath & Body > Liquid & Powdered Hand Soap',
#        'Home & Garden > Lawn & Garden > Gardening > Pots, Planters & Liners',
#        'Home & Garden > Household Appliances > Vacuums & Accessories',
#        'Home & Garden > Decor > Figurines & Miniatures',
#        'Household Supplies > Household Storage & Organization > Storage Hooks & Racks > Utility Hooks & Wall Mounting Supplies',
#        'Deli & Bakery > Bakery > Baked Goods & Desserts',
#        'Animals & Pet Supplies > Cat Supplies > Cat Litter, Litter Boxes & Accessories',
#        'Animals & Pet Supplies > Other Animal Supplies',
#        'Health & Wellness > Medical Supplies & Equipment',
#        'Dairy > Yogurt > Greek & High-Protein Yogurt',
#        'Beauty > Makeup > Eye Makeup > Mascara', 'Pantry > Dressings',
#        'Beverages > Carbonated Soft Drinks > Soda',
#        'Frozen > Frozen Meat > Frozen Seafood > Frozen Shellfish',
#        'Health & Wellness > Menstrual Care > Menstrual Care Pads',
#        'Frozen > Frozen Meat > Frozen Chicken > Frozen Chicken Wings',
#        'Health & Wellness > Bath & Body > Bath & Body Gift Sets',
#        'Deli & Bakery > Deli Counter > Sliced Deli Cheese',
#        'Home & Garden > Decor > Home Fragrances > Air Fresheners',
#        'Snacks > Snack Cakes > Cakes & Truffles Snack Cakes',
#        'Household Supplies > Household Cleaning Supplies',
#        'Meat & Seafood > Sausage & Cured Meats > Sausage Links & Bratwurst',
#        'Dairy > Cheese > Cottage Cheese',
#        'Pantry > Packaged Seafood > Packaged Tuna',
#        'Pantry > Packaged Meat > Packaged Chicken',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Entrees > Meal Kits',
#        'Frozen > Frozen Meat > Frozen Seafood',
#        'Pantry > Cooking & Baking > Spices & Seasonings',
#        'Household Supplies > Household Paper Products > Facial Tissues',
#        'Snacks > Chips > Tortilla Chips', 'Fees > Taxes > Sales Tax',
#        'Beverages > Carbonated Soft Drinks > Cola > Regular Cola',
#        'Frozen > Frozen Sides > Frozen French Fries',
#        'Pantry > Sauces & Marinades > Taco Sauce',
#        'Frozen > Frozen Sides',
#        'Snacks > Puffed Snacks > Popcorn > Microwave Popcorn',
#        'Pantry > Packaged Fruit & Applesauce > Cranberry Sauce',
#        'Animals & Pet Supplies > Cat Supplies > Cat Food',
#        'Alcohol > Hard Ciders', 'Produce > Fresh Fruits > Fresh Peaches',
#        'Alcohol > Spirits > Tequila',
#        'Pantry > Dressings > Ranch Dressing',
#        'Pantry > Packaged Meals & Sides > Microwavable Sides > Microwavable Non-Potato Sides',
#        'Home & Garden > Decor > Home Fragrances > Candles',
#        'Pantry > Cereal, Granola, & Toaster Pastries > Granola',
#        'Snacks > Crackers > Corn & Rice Cakes',
#        'Pantry > Cooking & Baking > Baking Mixes > Other Baking Mixes',
#        'Beverages > Energy Drinks',
#        'Snacks > Crackers > Sandwich Crackers',
#        'Pantry > Bread > Prepared Pizza Crust',
#        'Meat & Seafood > Fresh Beef > Fresh Ground Beef',
#        'Pantry > Cooking & Baking > Spices & Seasonings > Taco Seasoning',
#        'Pantry > Sauces & Marinades > Hot Sauce > Wing Sauce',
#        'Pantry > Cooking & Baking > Baking Staples > Sprinkles & Decorations',
#        'Dairy > Refrigerated Doughs > Refrigerated Sweet Rolls',
#        'Office & School > Filing & Organization > Folders & Report Covers > Pocket Folders',
#        'Baby & Toddler > Baby & Toddler Feeding > Baby & Toddler Food > Toddler Nutrition Drinks & Shakes',
#        'Apparel & Accessories > Clothing > Baby & Toddler Clothing > Baby & Toddler Sleepwear',
#        'Health & Wellness > Medicines & Treatments > Cough & Cold Medicines & Treatments > Immune Support',
#        'Produce > Salad Mixes > Fresh Salad Mixes',
#        'Pantry > Pickled Goods > Pickles',
#        'Alcohol > Beer > Lager > American Lager > Light American Lager',
#        'Animals & Pet Supplies > Pet Grooming Supplies',
#        'Frozen > Frozen Breads & Doughs > Frozen Bread Loaves',
#        'Produce > Fresh Vegetables > Fresh Onions & Garlic',
#        'Pantry > Cooking & Baking > Spices & Seasonings > Garlic & Onion Spices & Seasonings',
#        'Health & Wellness > Oral Care > Floss',
#        'Arts & Entertainment > Party & Celebration > Gift Giving > Gift Wrapping',
#        'Produce > Fresh Fruits > Fresh Pineapples',
#        'Pantry > Bread > Bread Loaves > Sandwich Bread',
#        'Home & Garden > Kitchen & Dining > Kitchen Tools & Utensils > Kitchen Slicers',
#        'Household Supplies > Food Storage > Food Storage Bags',
#        'Snacks > Snack Cakes > Brownie Snack Cakes',
#        'Beverages > Fruit & Vegetable Juices > Apple Juice & Cider',
#        'Pantry > Bread > Tortillas, Shells, & Wraps > Wraps & Tortillas',
#        'Snacks > Jerky & Dried Meat > Jerky & Bites',
#        'Apparel & Accessories > Clothing > Dresses',
#        'Pantry > Packaged Meals & Sides > Microwavable Sides > Microwavable Potato Sides',
#        'Snacks > Chips',
#        'Apparel & Accessories > Clothing > Underwear & Socks > Bras & Accessories',
#        'Pantry > Packaged Fruit & Applesauce > Applesauce',
#        'Pantry > Cooking & Baking > Spices & Seasonings > Herbs',
#        'Health & Wellness > Oral Care > Mouthwash',
#        'Frozen > Frozen Breads & Doughs > Frozen Dough & Pizza Crusts',
#        'Pantry > Cereal, Granola, & Toaster Pastries > Oatmeal & Hot Cereal',
#        'Frozen > Frozen Pizza & Pizza Snacks > Frozen Pizza Rolls',
#        'Produce > Fresh Fruits > Fresh Tropical Fruits',
#        'Health & Wellness > Medicines & Treatments > Pain & Fever Medicines & Treatments',
#        'Beverages > Fruit & Vegetable Juices > Tomato Juice',
#        "Health & Wellness > Hair Removal > Shaving Gel & Cream > Women's Shaving Gel & Cream",
#        'Beverages > Water > Purified Water > Purified Unflavored Water',
#        'Home & Garden > Decor > Throw Pillows',
#        'Pantry > Packaged Vegetables > Tomatoes',
#        'Dairy > Eggs > Fresh Eggs',
#        'Pantry > Sauces & Marinades > Soy & Fish Sauce',
#        'Snacks > Crackers > Butter Crackers',
#        'Snacks > Puffed Snacks > Cheese Curls & Puffs',
#        'Snacks > Snack Bars > Cereal Bars & Breakfast Biscuits',
#        'Pantry > Soup & Broth > Broth, Bouillon, & Stock',
#        'Health & Wellness > Menstrual Care > Menstrual Care Liners',
#        'Frozen > Frozen Meat > Frozen Chicken > Frozen Chicken Nuggets & Patties',
#        'Snacks > Candy > Gum',
#        "Health & Wellness > Deodorant & Antiperspirant > Men's Deodorant & Antiperspirant",
#        "Health & Wellness > Deodorant & Antiperspirant > Women's Deodorant & Antiperspirant",
#        'Home & Garden > Kitchen & Dining > Kitchen Tools & Utensils > Pizza Cutters',
#        'Luggage & Bags > Backpacks',
#        'Household Supplies > Food Storage > Foil',
#        'Beauty > Nail Care > Manicure Glue', 'Dairy > Eggs',
#        "Dairy > Yogurt > Kids' Yogurt",
#        'Beverages > Coffee > Coffee Pods',
#        'Alcohol > Beer > Ale > India Pale Ale (IPA)',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Oven & Grill Cleaners',
#        'Beverages > Drink Mixes > Chocolate Drink Mixes',
#        'Meat & Seafood > Lunch Meat',
#        'Animals & Pet Supplies > Cat Supplies > Cat Treats',
#        'Produce > Fresh Fruits > Fresh Bananas',
#        'Frozen > Frozen Breakfast > Frozen Breakfast Pastries',
#        'Frozen > Frozen Breakfast > Frozen Breakfast Entrées',
#        'Pantry > Soup & Broth > Dry Soup Mix',
#        'Health & Wellness > Hair Care > Shampoo',
#        'Alcohol > Wine > White Wine > Chardonnay',
#        'Produce > Fresh Herbs',
#        'Household Supplies > Pest Control > Pest Control Traps',
#        'Pantry > Cooking & Baking > Flour & Meal > Corn & Cracker Meal',
#        'Baby & Toddler > Baby Bathing > Baby Lotions & Oils',
#        'Beverages > Carbonated Soft Drinks > Soda > Citrus Soda',
#        'Snacks > Dessert Toppings > Ice Cream Cones',
#        'Animals & Pet Supplies > Dog Supplies > Dog Treats',
#        'Health & Wellness > Bath & Body > Hand Sanitizer',
#        'Pantry > Condiments > Relish',
#        'Health & Wellness > Oral Care > Toothpaste',
#        'Frozen > Frozen Fruits > Frozen Mixed Fruits',
#        'Snacks > Nuts & Seeds > Almonds', 'Apparel & Accessories > Shoes',
#        'Dairy > Refrigerated Doughs > Refrigerated Pie Dough & Crust',
#        'Pantry > Cooking & Baking > Pasta Sauce > Pesto Sauce',
#        'Snacks > Pretzels',
#        'Baby & Toddler > Baby Health > Baby Health & Grooming Kits',
#        'Dairy > Milk', 'Vehicles & Parts > Motor Vehicle Electronics',
#        'Alcohol > Spirits > Prepared Cocktails',
#        'Produce > Fresh Vegetables > Fresh Peppers',
#        'Frozen > Frozen Desserts > Frozen Pies',
#        'Pantry > Cooking & Baking > Baking Mixes > Brownie & Dessert Bar Baking Mixes',
#        'Health & Wellness > Hair Care > Hair Styling Products',
#        'Home & Garden > Decor > Baskets',
#        'Beauty > Tanning Products > Self Tanner',
#        "Health & Wellness > Hair Removal > Razors > Men's Razors",
#        'Produce > Fresh Vegetables > Fresh Corn', 'Snacks',
#        'Electronics > Electronics Accessories > Power',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Entrees > Ramen & Instant Noodles',
#        'Snacks > Snack Cakes > Pies & Tarts Snack Cakes',
#        'Pantry > Sauces & Marinades',
#        'Beverages > Juice Drink > Juice Boxes & Juice Pouches',
#        'Frozen > Frozen Desserts > Frozen Dairy Desserts > Ice Cream',
#        'Electronics > Cameras & Optics > Cameras',
#        'Pantry > Pasta & Noodles > Dry Pasta',
#        'Home & Garden > Kitchen & Dining > Food & Beverage Carriers > Water Bottles',
#        'Household Supplies > Household Paper Products > Paper Towels',
#        'Health & Wellness > Hair Care',
#        'Electronics > Electronics Accessories > Power > Batteries',
#        'Frozen > Frozen Meals > Frozen Single Serve Meals',
#        'Snacks > Nuts & Seeds > Peanuts',
#        'Beverages > Carbonated Soft Drinks > Cola > Diet Cola',
#        'Electronics > Electronics Accessories > Remote Controls',
#        'Pantry > Bread > Tortillas, Shells, & Wraps > Tostadas & Crunchy Taco Shells',
#        'Pantry > Cereal, Granola, & Toaster Pastries > Toaster Pastries',
#        'Household Supplies > Waste Containment > Garbage Bags',
#        'Snacks > Cookies', 'Pantry > Packaged Vegetables',
#        'Meat & Seafood > Fresh Chicken > Fresh Whole Chickens',
#        'Household Supplies > Household Cleaning Supplies > Household Cleaning Products > Tub & Tile Cleaners',
#        'Apparel & Accessories > Clothing > Baby & Toddler Clothing > Baby One-Pieces',
#        'Produce > Fresh Fruits > Fresh Berries > Fresh Raspberries',
#        'Beverages > Drink Mixes > Fruit Drink Mixes',
#        'Household Supplies > Laundry Supplies > Laundry Detergent',
#        'Beverages > Carbonated Soft Drinks > Soda > Root Beer',
#        'Snacks > Crackers > Saltine Crackers', 'Snacks > Snack Mixes',
#        'Meat & Seafood > Fresh Pork > Ground Pork',
#        'Baby & Toddler > Diapering > Diapers',
#        'Home & Garden > Kitchen & Dining > Outdoor Grilling > Charcoal Briquettes',
#        'Alcohol > Spirits > Whiskey > Bourbon', 'Snacks > Candy > Mints',
#        'Snacks > Snack Cakes > Danishes & Puffs Snack Cakes',
#        'Apparel & Accessories > Clothing Accessories > Belts & Accessories',
#        'Office & School > Office Instruments > Writing & Drawing Instruments > Markers & Highlighters > Highlighters',
#        'Meat & Seafood > Sausage & Cured Meats > Bulk Sausage',
#        'Fees > Bottle Deposits',
#        'Alcohol > Hard Seltzers, Sodas, Waters, Lemonades & Teas > Hard Seltzer & Still Water',
#        'Pantry > Packaged Meals & Sides > Stovetop & Oven Sides > Stovetop Pasta Sides',
#        'Pantry > Condiments > BBQ Sauce',
#        'Meat & Seafood > Fresh Chicken > Fresh Chicken Wings',
#        'Meat & Seafood > Fresh Chicken > Fresh Chicken Legs & Thighs',
#        'Animals & Pet Supplies > Dog Supplies > Dog Diapers & Pads',
#        'Household Supplies > Household Cleaning Supplies > Mops & Accessories',
#        'Electronics > Audio > Audio Components > Headphones, Ear Buds & Accessories',
#        'Dairy > Refrigerated Doughs > Refrigerated Crescent Rolls, Biscuit & Bread Dough',
#        'Home & Garden > Kitchen & Dining > Outdoor Grilling',
#        'Baby & Toddler > Baby Toys & Activity Equipment',
#        'Pantry > Bread > Tortillas, Shells, & Wraps > Pita & Lavash Bread',
#        'Pantry > Cooking & Baking > Sugars & Sweeteners > Brown Sugar',
#        'Snacks > Candy > Chocolate Candy',
#        'Snacks > Chips > Bagel & Pita Chips',
#        'Animals & Pet Supplies > Pet Medicine > Pet Supplements'],
#       dtype=object)

# %%
tree = CategoryTree()
for category in categories_hierarchy:
    tree.add_category_path(category)

# tree.display_tree()

# %%
agent = CategoryAssignmentAgent(tree, OPENAI_API_KEY)

# %%
index = 1
product_description = df.iloc[index, 0]
true_category = df.iloc[index, 10]
result = agent.assign_category(product_description)

# %%
print(result["product_description"])
print(true_category)
print(result["messages"][-1].content)
# Out:
# ole seoky pineap bottle
# Beverages > Fruit & Vegetable Juices > Other Juices
# {
#     "category_path": "Beverages > Fruit & Vegetable Juices > Other Juices",
#     "reasoning": "Step 1: The product name 'ole seoky pineap bottle' suggests a beverage, likely a pineapple-flavored drink in a bottle. Among the root categories, 'Beverages' is the most appropriate, as the product does not fit apparel, pantry, or other categories. Step 2: Within 'Beverages', the options include various drink types. Since the product likely contains pineapple, a fruit, 'Fruit & Vegetable Juices' is the best fit. Step 3: Within 'Fruit & Vegetable Juices', there are specific juice types, but none for pineapple. 'Other Juices' is the most suitable subcategory for juices not specifically listed. Step 4: 'Other Juices' is a leaf node, so the process stops here.",
#     "confidence": "high",
#     "is_complete": true,
#     "steps": [
#         {
#             "level": 1,
#             "category": "Beverages",
#             "reasoning": "The product appears to be a bottled drink, which fits best under 'Beverages'. Other categories like Pantry, Snacks, or Produce are less relevant.",
#             "confidence": "high"
#         },
#         {
#             "level": 2,
#             "category": "Fruit & Vegetable Juices",
#             "reasoning": "The mention of 'pineap' (likely pineapple) suggests a fruit juice. Other beverage types (coffee, tea, soda) do not fit.",
#             "confidence": "high"
#         },
#         {
#             "level": 3,
#             "category": "Other Juices",
#             "reasoning": "There is no specific pineapple juice category, and 'Other Juices' is intended for fruit juices not otherwise specified.",
#             "confidence": "high"
#         }
#     ]
# }

# %%
# Evaluate the agent's performance
async def predict_category(agent, df):
    """Evaluate the agent's performance on the dataset."""
    correct = 0
    total = len(df)

    async def process_row(row):
        product_description = row.ORIGINAL_ITEM_TEXT
        true_category = row.CATEGORY_NAME_HIERARCHY
        result = await agent.assign_category_async(product_description)
        predicted_category = result["messages"][-1].content
        # Load as json
        predicted_category = json.loads(predicted_category)
        input_text = result["product_description"]
        predicted_category = predicted_category["category_path"]
        return (input_text, predicted_category, true_category)

    tasks = [process_row(row) for row in df.itertuples()]
    results = []

    # Process rows concurrently with tqdm progress bar
    for result in tqdm_asyncio.as_completed(tasks, total=total):
        results.append(await result)

    return results


# Run the evaluation
import nest_asyncio

nest_asyncio.apply()

results = await predict_category(agent, df.sample(500))
# Out:
# 100%|██████████| 500/500 [00:33<00:00, 14.90it/s]

# %%
# Create dataframe of results
prediction_df = pd.DataFrame(results, columns=["product_description", "predicted_categories", "true_categories"])

# %%
prediction_df["true_cat_tier1"] = prediction_df["true_categories"].apply(
    lambda x: x.split(">")[0] if len(x.split(">")) > 0 else None
)
prediction_df["true_cat_tier2"] = prediction_df["true_categories"].apply(
    lambda x: x.split(">")[1] if len(x.split(">")) > 1 else None
)
prediction_df["true_cat_tier3"] = prediction_df["true_categories"].apply(
    lambda x: x.split(">")[2] if len(x.split(">")) > 2 else None
)
prediction_df["pred_cat_tier1"] = prediction_df["predicted_categories"].apply(
    lambda x: x.split(">")[0] if len(x.split(">")) > 0 else None
)
prediction_df["pred_cat_tier2"] = prediction_df["predicted_categories"].apply(
    lambda x: x.split(">")[1] if len(x.split(">")) > 1 else None
)
prediction_df["pred_cat_tier3"] = prediction_df["predicted_categories"].apply(
    lambda x: x.split(">")[2] if len(x.split(">")) > 2 else None
)

# %%
# accuracy of tier 1
print((prediction_df["true_cat_tier1"] == prediction_df["pred_cat_tier1"]).mean())
# accuracy of tier 2
print((prediction_df["true_cat_tier2"] == prediction_df["pred_cat_tier2"]).mean())
# accuracy of tier 3
print((prediction_df["true_cat_tier3"] == prediction_df["pred_cat_tier3"]).mean())
# full accuracy
print((prediction_df["true_categories"] == prediction_df["predicted_categories"]).mean())
# Out:
# 0.73
# 0.582
# 0.486
# 0.534
